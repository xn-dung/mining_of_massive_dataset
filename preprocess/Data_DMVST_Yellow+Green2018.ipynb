# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import numpy as np

YELLOW_PATH = "/content/drive/MyDrive/Mining of massive dataset/preprocessing_output/yellow_data/yellow_2018/taxi_volume_4d_tensor_final.npy"
GREEN_PATH = "/content/drive/MyDrive/Mining of massive dataset/preprocessing_output/green_data/green_2018/taxi_volume_4d_tensor_final_green.npy"
OUT_PATH = "/content/drive/MyDrive/Mining of massive dataset/preprocessing_output/taxi_volume_4d_tensor_sum.npy"

# %%
yellow = np.load(YELLOW_PATH)
green  = np.load(GREEN_PATH)

# %%
assert yellow.shape == green.shape, f"Shape mismatch: {yellow.shape} vs {green.shape}"

combined = yellow + green
np.save(OUT_PATH, combined)

# %%
print("Saved:", OUT_PATH, "shape:", combined.shape)
# Out:
# Saved: /content/drive/MyDrive/Mining of massive dataset/preprocessing_output/taxi_volume_4d_tensor_sum.npy shape: (17519, 3, 10, 20)
